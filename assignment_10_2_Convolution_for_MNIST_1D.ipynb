# %% [markdown]
# <a href="https://colab.research.google.com/github/Kulnoorbajwa/CSCI-167--Deep-learning-/blob/main/assignment_10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-tdso24fe
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-tdso24fe
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=09886a1fb3580efdc23fa9242e042b25c5ab247264b25092888acdc645b0d658
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y_50hyrc/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(in_features=4*15, out_features=10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.001790, train error 77.65,  val loss 2.023837, percent error 77.40
# Epoch     1, train loss 1.617613, train error 64.50,  val loss 1.640553, percent error 69.50
# Epoch     2, train loss 1.371238, train error 56.08,  val loss 1.381660, percent error 58.40
# Epoch     3, train loss 1.301031, train error 53.72,  val loss 1.318811, percent error 55.20
# Epoch     4, train loss 1.229529, train error 51.40,  val loss 1.239141, percent error 52.60
# Epoch     5, train loss 1.200446, train error 49.30,  val loss 1.238356, percent error 51.80
# Epoch     6, train loss 1.112337, train error 46.53,  val loss 1.150666, percent error 48.00
# Epoch     7, train loss 1.078781, train error 44.72,  val loss 1.109668, percent error 45.10
# Epoch     8, train loss 0.976395, train error 37.62,  val loss 1.015807, percent error 42.20
# Epoch     9, train loss 0.927052, train error 37.90,  val loss 0.956746, percent error 38.20
# Epoch    10, train loss 0.826910, train error 32.57,  val loss 0.875118, percent error 36.30
# Epoch    11, train loss 0.789264, train error 30.80,  val loss 0.821676, percent error 33.60
# Epoch    12, train loss 0.674783, train error 26.93,  val loss 0.723672, percent error 28.20
# Epoch    13, train loss 0.657655, train error 25.90,  val loss 0.748040, percent error 29.70
# Epoch    14, train loss 0.752359, train error 28.28,  val loss 0.822475, percent error 28.60
# Epoch    15, train loss 0.525827, train error 20.00,  val loss 0.634682, percent error 24.20
# Epoch    16, train loss 0.536502, train error 21.28,  val loss 0.620540, percent error 25.40
# Epoch    17, train loss 0.469752, train error 18.07,  val loss 0.569712, percent error 22.40
# Epoch    18, train loss 0.456170, train error 17.85,  val loss 0.543360, percent error 21.50
# Epoch    19, train loss 0.410030, train error 15.60,  val loss 0.502017, percent error 19.00
# Epoch    20, train loss 0.361035, train error 14.03,  val loss 0.467276, percent error 18.00
# Epoch    21, train loss 0.363177, train error 13.68,  val loss 0.483350, percent error 18.20
# Epoch    22, train loss 0.310470, train error 11.07,  val loss 0.441116, percent error 16.30
# Epoch    23, train loss 0.282704, train error 9.95,  val loss 0.410096, percent error 14.90
# Epoch    24, train loss 0.264629, train error 9.55,  val loss 0.401631, percent error 14.90
# Epoch    25, train loss 0.258817, train error 9.68,  val loss 0.384828, percent error 13.80
# Epoch    26, train loss 0.247663, train error 8.82,  val loss 0.368238, percent error 12.40
# Epoch    27, train loss 0.235202, train error 8.32,  val loss 0.374869, percent error 12.70
# Epoch    28, train loss 0.199669, train error 6.95,  val loss 0.338658, percent error 11.80
# Epoch    29, train loss 0.205414, train error 7.78,  val loss 0.366021, percent error 11.60
# Epoch    30, train loss 0.182474, train error 6.32,  val loss 0.344513, percent error 11.90
# Epoch    31, train loss 0.164598, train error 5.47,  val loss 0.332221, percent error 10.70
# Epoch    32, train loss 0.158799, train error 5.53,  val loss 0.348471, percent error 11.00
# Epoch    33, train loss 0.169814, train error 6.10,  val loss 0.341272, percent error 10.80
# Epoch    34, train loss 0.158692, train error 5.53,  val loss 0.322937, percent error 10.30
# Epoch    35, train loss 0.148715, train error 5.07,  val loss 0.338133, percent error 10.20
# Epoch    36, train loss 0.141928, train error 4.85,  val loss 0.331289, percent error 9.60
# Epoch    37, train loss 0.120524, train error 4.15,  val loss 0.303064, percent error 8.90
# Epoch    38, train loss 0.115404, train error 4.05,  val loss 0.287602, percent error 9.20
# Epoch    39, train loss 0.116900, train error 4.38,  val loss 0.302879, percent error 9.20
# Epoch    40, train loss 0.094471, train error 3.05,  val loss 0.288856, percent error 9.20
# Epoch    41, train loss 0.093294, train error 3.00,  val loss 0.300102, percent error 8.60
# Epoch    42, train loss 0.086529, train error 2.47,  val loss 0.302929, percent error 9.00
# Epoch    43, train loss 0.084256, train error 2.53,  val loss 0.298869, percent error 8.60
# Epoch    44, train loss 0.084772, train error 2.70,  val loss 0.306386, percent error 8.90
# Epoch    45, train loss 0.085485, train error 2.55,  val loss 0.310186, percent error 9.10
# Epoch    46, train loss 0.076839, train error 2.32,  val loss 0.304265, percent error 8.50
# Epoch    47, train loss 0.072831, train error 2.03,  val loss 0.302264, percent error 8.60
# Epoch    48, train loss 0.071478, train error 2.10,  val loss 0.303883, percent error 8.50
# Epoch    49, train loss 0.070911, train error 2.15,  val loss 0.301111, percent error 8.90
# Epoch    50, train loss 0.077711, train error 2.45,  val loss 0.308966, percent error 9.50
# Epoch    51, train loss 0.073148, train error 2.28,  val loss 0.312226, percent error 9.20
# Epoch    52, train loss 0.068020, train error 2.12,  val loss 0.314059, percent error 8.80
# Epoch    53, train loss 0.068042, train error 2.18,  val loss 0.319569, percent error 9.20
# Epoch    54, train loss 0.063791, train error 1.78,  val loss 0.311379, percent error 8.60
# Epoch    55, train loss 0.064505, train error 1.90,  val loss 0.317844, percent error 8.50
# Epoch    56, train loss 0.064436, train error 1.72,  val loss 0.321364, percent error 8.90
# Epoch    57, train loss 0.056093, train error 1.47,  val loss 0.315294, percent error 8.70
# Epoch    58, train loss 0.056370, train error 1.47,  val loss 0.318527, percent error 8.50
# Epoch    59, train loss 0.057508, train error 1.50,  val loss 0.324977, percent error 8.80
# Epoch    60, train loss 0.051875, train error 1.30,  val loss 0.313504, percent error 8.50
# Epoch    61, train loss 0.049209, train error 1.10,  val loss 0.316446, percent error 8.70
# Epoch    62, train loss 0.048952, train error 1.15,  val loss 0.320607, percent error 8.80
# Epoch    63, train loss 0.048250, train error 1.12,  val loss 0.326222, percent error 8.50
# Epoch    64, train loss 0.047738, train error 1.12,  val loss 0.321057, percent error 9.00
# Epoch    65, train loss 0.049638, train error 1.32,  val loss 0.325800, percent error 8.50
# Epoch    66, train loss 0.046332, train error 1.05,  val loss 0.323546, percent error 8.70
# Epoch    67, train loss 0.046250, train error 0.95,  val loss 0.323429, percent error 8.80
# Epoch    68, train loss 0.045228, train error 0.95,  val loss 0.332498, percent error 9.10
# Epoch    69, train loss 0.043956, train error 0.93,  val loss 0.327093, percent error 8.50
# Epoch    70, train loss 0.044145, train error 0.95,  val loss 0.334098, percent error 9.10
# Epoch    71, train loss 0.043057, train error 0.88,  val loss 0.328800, percent error 8.60
# Epoch    72, train loss 0.043917, train error 0.93,  val loss 0.336601, percent error 8.80
# Epoch    73, train loss 0.047069, train error 1.18,  val loss 0.339901, percent error 8.90
# Epoch    74, train loss 0.043664, train error 0.88,  val loss 0.337110, percent error 8.70
# Epoch    75, train loss 0.041213, train error 0.88,  val loss 0.335582, percent error 9.00
# Epoch    76, train loss 0.041443, train error 0.75,  val loss 0.339663, percent error 8.80
# Epoch    77, train loss 0.042131, train error 0.93,  val loss 0.342153, percent error 8.50
# Epoch    78, train loss 0.039705, train error 0.65,  val loss 0.337012, percent error 8.90
# Epoch    79, train loss 0.040817, train error 0.80,  val loss 0.347129, percent error 9.10
# Epoch    80, train loss 0.038491, train error 0.68,  val loss 0.340963, percent error 9.00
# Epoch    81, train loss 0.038361, train error 0.60,  val loss 0.341220, percent error 9.00
# Epoch    82, train loss 0.037911, train error 0.65,  val loss 0.339770, percent error 9.00
# Epoch    83, train loss 0.037576, train error 0.65,  val loss 0.342273, percent error 8.90
# Epoch    84, train loss 0.037490, train error 0.57,  val loss 0.341899, percent error 8.90
# Epoch    85, train loss 0.037781, train error 0.62,  val loss 0.345290, percent error 8.80
# Epoch    86, train loss 0.037082, train error 0.62,  val loss 0.342603, percent error 9.00
# Epoch    87, train loss 0.037410, train error 0.60,  val loss 0.346240, percent error 9.00
# Epoch    88, train loss 0.036488, train error 0.60,  val loss 0.343109, percent error 9.00
# Epoch    89, train loss 0.036426, train error 0.55,  val loss 0.344119, percent error 8.90
# Epoch    90, train loss 0.036142, train error 0.57,  val loss 0.345553, percent error 8.60
# Epoch    91, train loss 0.035894, train error 0.60,  val loss 0.344823, percent error 8.90
# Epoch    92, train loss 0.035689, train error 0.50,  val loss 0.348094, percent error 9.40
# Epoch    93, train loss 0.035626, train error 0.60,  val loss 0.347021, percent error 9.00
# Epoch    94, train loss 0.035917, train error 0.53,  val loss 0.349730, percent error 9.00
# Epoch    95, train loss 0.035778, train error 0.65,  val loss 0.347203, percent error 8.70
# Epoch    96, train loss 0.034977, train error 0.53,  val loss 0.349849, percent error 9.10
# Epoch    97, train loss 0.034721, train error 0.57,  val loss 0.349649, percent error 9.00
# Epoch    98, train loss 0.034446, train error 0.55,  val loss 0.348978, percent error 9.10
# Epoch    99, train loss 0.034235, train error 0.45,  val loss 0.350019, percent error 9.10
